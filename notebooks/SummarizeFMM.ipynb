# %%
import pandas as pd
import numpy as np
import os
import json
import altair as alt

# %%
JSON_FILE = "../results/REV3L/REV3L_codons.fasta.FMM.json"
pvalueThreshold = 0.1

# %%
def getData(json_file):
    with open(json_file, "r") as in_d:
        json_data = json.load(in_d)
    return json_data["Evidence Ratios"]
#end method

def getFits(json_file):
    with open(json_file, "r") as in_d:
        json_data = json.load(in_d)
    return json_data["fits"]
#end method

# %%
json_file = JSON_FILE
with open(json_file, "r") as in_d:
    json_data = json.load(in_d)
    
print(json_data.keys())
print(json_data["Evidence Ratios"].keys())
# Out:
# dict_keys(['Evidence Ratios', 'Site Log Likelihood', 'Site substitutions', 'analysis', 'branch attributes', 'data partitions', 'fits', 'input', 'test results', 'tested', 'timers'])
# dict_keys(['Double-hit vs Single-hit', 'Triple-hit islands vs Double-hit', 'Triple-hit vs Double-hit', 'Triple-hit vs Triple-hit islands'])

# %%
df = ""
for key in json_data["Evidence Ratios"].keys():
    print(key)
    if type(df) != str:
        df2 = pd.DataFrame.from_dict(getData(JSON_FILE)[key]).T
        df2 = df2.rename(columns={0:key})
        df2[key] = 2 * np.log(df2[key])
        df[key] = df2[key]
    else:
        df = pd.DataFrame.from_dict(getData(JSON_FILE)[key]).T
        df = df.rename(columns={0:key})
        df[key] = 2 * np.log(df[key])
    #end if
    #print(df)
#end for

df.index += 1
df["Site"] = df.index
df
# Out:
# Double-hit vs Single-hit
# Triple-hit islands vs Double-hit
# Triple-hit vs Double-hit
# Triple-hit vs Triple-hit islands
#       Double-hit vs Single-hit  Triple-hit islands vs Double-hit  \
# 1                 2.789480e-02                      4.665180e-04
# 2                 6.705696e-01                     -4.672137e-02
# 3                -8.881784e-15                      3.996803e-15
# 4                 1.598721e-14                     -4.440892e-15
# 5                -4.440892e-15                     -4.440892e-15
# ...                        ...                               ...
# 4730             -8.699642e-01                     -4.767741e-02
# 4731             -3.602706e-02                      3.261463e-02
# 4732             -8.674581e-02                     -8.051151e-02
# 4733              1.214626e+01                     -2.630457e-01
# 4734              6.302404e+00                     -5.709443e-02
#
#       Triple-hit vs Double-hit  Triple-hit vs Triple-hit islands  Site
# 1                 4.438707e-03                      3.972189e-03     1
# 2                -3.710748e-01                     -3.243534e-01     2
# 3                 7.993606e-15                      2.220446e-15     3
# 4                -5.329071e-15                     -8.881784e-16     4
# 5                 2.220446e-15                      7.993606e-15     5
# ...                        ...                               ...   ...
# 4730              3.882716e-01                      4.359490e-01  4730
# 4731              7.584476e-01                      7.258330e-01  4731
# 4732             -1.310963e-01                     -5.058475e-02  4732
# 4733             -2.287255e+00                     -2.024209e+00  4733
# 4734              5.050189e+00                      5.107283e+00  4734
#
# [4734 rows x 5 columns]

# %%
df.T
# Out:
#                                       1         2             3     \
# Double-hit vs Single-hit          0.027895  0.670570 -8.881784e-15
# Triple-hit islands vs Double-hit  0.000467 -0.046721  3.996803e-15
# Triple-hit vs Double-hit          0.004439 -0.371075  7.993606e-15
# Triple-hit vs Triple-hit islands  0.003972 -0.324353  2.220446e-15
# Site                              1.000000  2.000000  3.000000e+00
#
#                                           4             5             6     \
# Double-hit vs Single-hit          1.598721e-14 -4.440892e-15 -3.552714e-15
# Triple-hit islands vs Double-hit -4.440892e-15 -4.440892e-15  6.217249e-15
# Triple-hit vs Double-hit         -5.329071e-15  2.220446e-15  0.000000e+00
# Triple-hit vs Triple-hit islands -8.881784e-16  7.993606e-15 -5.329071e-15
# Site                              4.000000e+00  5.000000e+00  6.000000e+00
#
#                                           7         8         9          10    \
# Double-hit vs Single-hit         -1.776357e-15  1.430421  3.143099  25.062271
# Triple-hit islands vs Double-hit  0.000000e+00 -0.032958 -0.072623  -0.374966
# Triple-hit vs Double-hit          2.220446e-15 -0.541714  2.779274   8.958423
# Triple-hit vs Triple-hit islands  2.220446e-15 -0.508756  2.851897   9.333389
# Site                              7.000000e+00  8.000000  9.000000  10.000000
#
#                                   ...         4725         4726         4727  \
# Double-hit vs Single-hit          ...    -0.793757     7.205013     5.767245
# Triple-hit islands vs Double-hit  ...    -0.043224    -0.094686    -0.031383
# Triple-hit vs Double-hit          ...     0.268703     4.895046     5.728371
# Triple-hit vs Triple-hit islands  ...     0.311927     4.989731     5.759754
# Site                              ...  4725.000000  4726.000000  4727.000000
#
#                                          4728         4729         4730  \
# Double-hit vs Single-hit            -0.352849    -0.452757    -0.869964
# Triple-hit islands vs Double-hit     0.044458     0.095039    -0.047677
# Triple-hit vs Double-hit             0.186458     0.308665     0.388272
# Triple-hit vs Triple-hit islands     0.142000     0.213626     0.435949
# Site                              4728.000000  4729.000000  4730.000000
#
#                                          4731         4732         4733  \
# Double-hit vs Single-hit            -0.036027    -0.086746    12.146262
# Triple-hit islands vs Double-hit     0.032615    -0.080512    -0.263046
# Triple-hit vs Double-hit             0.758448    -0.131096    -2.287255
# Triple-hit vs Triple-hit islands     0.725833    -0.050585    -2.024209
# Site                              4731.000000  4732.000000  4733.000000
#
#                                          4734
# Double-hit vs Single-hit             6.302404
# Triple-hit islands vs Double-hit    -0.057094
# Triple-hit vs Double-hit             5.050189
# Triple-hit vs Triple-hit islands     5.107283
# Site                              4734.000000
#
# [5 rows x 4734 columns]

# %%
source = df

line = alt.Chart(source).mark_line().encode(
    x='Site',
    y='Triple-hit vs Double-hit'
).properties(
    width=800,
    height=600).interactive()

line
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.stocks()

alt.Chart(source).mark_line().encode(
    x='date',
    y='price',
    color='symbol',
    strokeDash='symbol',
)
# Out:
# alt.Chart(...)

# %%
source
# Out:
#     symbol       date   price
# 0     MSFT 2000-01-01   39.81
# 1     MSFT 2000-02-01   36.35
# 2     MSFT 2000-03-01   43.22
# 3     MSFT 2000-04-01   28.37
# 4     MSFT 2000-05-01   25.45
# ..     ...        ...     ...
# 555   AAPL 2009-11-01  199.91
# 556   AAPL 2009-12-01  210.73
# 557   AAPL 2010-01-01  192.06
# 558   AAPL 2010-02-01  204.62
# 559   AAPL 2010-03-01  223.02
#
# [560 rows x 3 columns]

# %%
import altair as alt
from vega_datasets import data

source = data.stocks()

alt.Chart(source).transform_filter(
    alt.datum.symbol != 'GOOG'
).mark_area().encode(
    x='date:T',
    y='price:Q',
    color='symbol:N',
    row=alt.Row('symbol:N', sort=['MSFT', 'AAPL', 'IBM', 'AMZN'])
).properties(height=50, width=400)
# Out:
# alt.Chart(...)

# %%
source
# Out:
#     symbol       date   price
# 0     MSFT 2000-01-01   39.81
# 1     MSFT 2000-02-01   36.35
# 2     MSFT 2000-03-01   43.22
# 3     MSFT 2000-04-01   28.37
# 4     MSFT 2000-05-01   25.45
# ..     ...        ...     ...
# 555   AAPL 2009-11-01  199.91
# 556   AAPL 2009-12-01  210.73
# 557   AAPL 2010-01-01  192.06
# 558   AAPL 2010-02-01  204.62
# 559   AAPL 2010-03-01  223.02
#
# [560 rows x 3 columns]
